# %% [markdown]
# ## Importing library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/user/.local/lib/python3.9/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
df = pd.read_csv("laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %% [markdown]
# ## Data understanding

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=["Unnamed: 0"], inplace =True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %% [markdown]
# ## Data Preprocessing & EDA

# %%
df["Ram"]= df["Ram"].str.replace("GB",'')

# %%
df["Weight"]= df["Weight"].str.replace("kg",'')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df["Weight"]=df["Weight"].astype('float32')

# %%
df["Ram"]=df["Ram"].astype('int32')

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/user/.local/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/user/.local/lib/python3.9/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/user/.local/lib/python3.9/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/user/.local/lib/python3.9/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (8.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/user/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /home/user/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/user/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.18.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2->seaborn) (2021.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/.local/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# /tmp/ipykernel_2974/344234588.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x =df["Company"], y = df['Price'])
plt.xticks(rotation =90)
plt.show()

# %%
# sns.countplot(df["TypeName"])
df['TypeName'].value_counts().plot(kind ="bar")
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x =df["TypeName"], y = df['Price'])
plt.xticks(rotation =90)
# plt.show()
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Ultrabook'),
#   Text(1, 0, 'Notebook'),
#   Text(2, 0, 'Netbook'),
#   Text(3, 0, 'Gaming'),
#   Text(4, 0, '2 in 1 Convertible'),
#   Text(5, 0, 'Workstation')])

# %%
df.sample(6)
# Out:
#       Company   TypeName  Inches                    ScreenResolution  \
# 794     Apple  Ultrabook    12.0  IPS Panel Retina Display 2304x1440
# 354   Toshiba   Notebook    15.6         IPS Panel Full HD 1920x1080
# 585       MSI     Gaming    17.3                   Full HD 1920x1080
# 1160   Lenovo  Ultrabook    14.0                   Full HD 1920x1080
# 241      Asus   Notebook    17.3                   Full HD 1920x1080
# 1245     Asus     Gaming    15.6         IPS Panel Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 794           Intel Core M 1.2GHz    8   512GB Flash Storage
# 354    Intel Core i7 6500U 2.5GHz   16             512GB SSD
# 585   Intel Core i7 6820HK 2.7GHz   16  128GB SSD +  1TB HDD
# 1160   Intel Core i7 6600U 2.6GHz    8             256GB SSD
# 241    Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
# 1245  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys  Weight      Price
# 794       Intel HD Graphics 5300    Mac OS X    0.92   62071.20
# 354          Nvidia GeForce 930M  Windows 10    2.40   74751.84
# 585      Nvidia GeForce GTX 980M  Windows 10    4.50  125154.72
# 1160       Intel HD Graphics 520   Windows 7    1.70   79866.72
# 241         Nvidia GeForce 150MX  Windows 10    2.10   61005.60
# 1245  Nvidia GeForce GTX 1050 Ti  Windows 10    2.50   85248.00

# %%
sns.distplot(df['Inches'])
# Out:
# /tmp/ipykernel_2974/1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x = df['Inches'], y = df["Price"])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# IPS Panel Touchscreen 1366x768                     3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# 2560x1440                                          3
# Touchscreen 2400x1600                              3
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: count, dtype: int64

# %%
df["TouchScreen"]= df["ScreenResolution"].apply(lambda x:1 if "Touchscreen" in x else 0)

# %%
df.sample(10)
# Out:
#       Company            TypeName  Inches  \
# 54       Acer            Notebook    15.6
# 1021  Toshiba           Ultrabook    13.3
# 1287       HP            Notebook    15.6
# 98       Asus            Notebook    15.6
# 198        HP              Gaming    17.3
# 596    Lenovo  2 in 1 Convertible    13.3
# 1040   Lenovo  2 in 1 Convertible    15.6
# 315      Dell            Notebook    15.6
# 831    Lenovo           Ultrabook    14.0
# 339      Dell            Notebook    15.6
#
#                                ScreenResolution                          Cpu  \
# 54                                     1366x768   Intel Core i3 7100U 2.4GHz
# 1021                          Full HD 1920x1080   Intel Core i5 6200U 2.3GHz
# 1287                                   1366x768   Intel Core i7 6500U 2.5GHz
# 98                            Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# 198                 IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 596   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 1040  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz
# 315                           Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
# 831                IPS Panel Quad HD+ 2560x1440   Intel Core i7 6600U 2.6GHz
# 339                           Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 54      4               1TB HDD    Intel HD Graphics 620  Windows 10    2.40
# 1021    8             256GB SSD    Intel HD Graphics 520  Windows 10    1.20
# 1287    6               1TB HDD       AMD Radeon R5 M330  Windows 10    2.19
# 98      6             256GB SSD      Nvidia GeForce 920M  Windows 10    2.00
# 198    16  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10    3.35
# 596     8             512GB SSD    Intel HD Graphics 620  Windows 10    1.37
# 1040    4             256GB SSD    Intel HD Graphics 520  Windows 10    1.80
# 315     8  128GB SSD +  1TB HDD           AMD Radeon 530  Windows 10    2.33
# 831    16             512GB SSD    Intel HD Graphics 520  Windows 10    1.10
# 339     8             256GB SSD     Nvidia GeForce 940MX  Windows 10    2.00
#
#           Price  TouchScreen
# 54     20459.52            0
# 1021   84715.20            0
# 1287   40705.92            0
# 98     30742.56            0
# 198    73473.12            0
# 596   107892.00            1
# 1040   45128.16            1
# 315    44968.32            0
# 831   111834.72            0
# 339    60885.72            0

# %%
df["TouchScreen"].value_counts().plot(kind ="bar")
# Out:
# <Axes: xlabel='TouchScreen'>

# %%
sns.barplot(x =df["TouchScreen"], y = df['Price'])
# Out:
# <Axes: xlabel='TouchScreen', ylabel='Price'>

# %%
df["Ips"]= df["ScreenResolution"].apply(lambda x:1 if "IPS" in x else 0)

# %%
df.sample(6)
# Out:
#       Company   TypeName  Inches                           ScreenResolution  \
# 191      Vero   Notebook    14.0                IPS Panel Full HD 1920x1080
# 68     Lenovo   Notebook    15.6                          Full HD 1920x1080
# 1038     Dell   Notebook    15.6                          Full HD 1920x1080
# 960   Toshiba   Notebook    13.3                          Full HD 1920x1080
# 422        HP   Notebook    15.6                          Full HD 1920x1080
# 1074   Lenovo  Ultrabook    12.5  IPS Panel Full HD / Touchscreen 1920x1080
#
#                                        Cpu  Ram              Memory  \
# 191   Intel Celeron Dual Core N3350 1.1GHz    4  32GB Flash Storage
# 68              Intel Core i5 7200U 2.5GHz    4             1TB HDD
# 1038            Intel Core i5 6300U 2.4GHz    8           256GB SSD
# 960             Intel Core i5 6300U 2.4GHz    8           256GB SSD
# 422            Intel Core i7 7820HQ 2.9GHz    8           256GB SSD
# 1074            Intel Core i7 6500U 2.5GHz    8           256GB SSD
#
#                         Gpu       OpSys  Weight       Price  TouchScreen  Ips
# 191   Intel HD Graphics 500  Windows 10    1.30  13852.8000            0    1
# 68    Intel HD Graphics 620  Windows 10    1.90  29250.7200            0    0
# 1038  Intel HD Graphics 520   Windows 7    2.09  56633.9760            0    0
# 960   Intel HD Graphics 520  Windows 10    1.20  81784.8000            0    0
# 422   Intel HD Graphics 630  Windows 10    2.31  76030.5600            0    0
# 1074  Intel HD Graphics 520  Windows 10    1.30  91294.7472            1    1

# %%
temp =df["ScreenResolution"].str.split('x',n=1,expand = True)

# %%
df['X_res'] = temp[0]

# %%
df['y_res'] = temp[1]

# %%
df.sample(6)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 295   Lenovo    Gaming    15.6  IPS Panel Full HD 1920x1080
# 77      Dell  Notebook    15.6            Full HD 1920x1080
# 93      Dell    Gaming    15.6            Full HD 1920x1080
# 1064     MSI    Gaming    15.6            Full HD 1920x1080
# 553       HP  Notebook    17.3                     1600x900
# 863   Lenovo    Gaming    15.6  IPS Panel Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 295   Intel Core i7 7700HQ 2.8GHz    8               1TB HDD
# 77     Intel Core i7 8550U 1.8GHz    8  128GB SSD +  1TB HDD
# 93    Intel Core i5 7300HQ 2.5GHz    8             256GB SSD
# 1064  Intel Core i7 6700HQ 2.6GHz   16  256GB SSD +  1TB HDD
# 553      Intel Core i3 6006U 2GHz    8               1TB HDD
# 863   Intel Core i5 7300HQ 2.5GHz    8               1TB HDD
#
#                           Gpu       OpSys  Weight       Price  TouchScreen  \
# 295   Nvidia GeForce GTX 1060  Windows 10    3.20   69210.720            0
# 77     Intel UHD Graphics 620  Windows 10    2.02   45554.400            0
# 93    Nvidia GeForce GTX 1060  Windows 10    2.65   63669.600            0
# 1064  Nvidia GeForce GTX 1060  Windows 10    1.80  102777.120            0
# 553     Intel HD Graphics 520  Windows 10    2.65   28992.312            0
# 863   Nvidia GeForce GTX 1050       No OS    2.50   54185.760            0
#
#       Ips                   X_res y_res
# 295     1  IPS Panel Full HD 1920  1080
# 77      0            Full HD 1920  1080
# 93      0            Full HD 1920  1080
# 1064    0            Full HD 1920  1080
# 553     0                    1600   900
# 863     1  IPS Panel Full HD 1920  1080

# %%
df["X_res"]= df["X_res"].str.extract('(\d+)')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# memory usage: 142.6+ KB

# %%
df['X_res']=df['X_res'].astype("int32")

# %%
df['y_res']=df['y_res'].astype("int32")

# %%
df['X_res']=df['X_res'].replace(4,3840)

# %%
df['X_res'].value_counts()
# Out:
# X_res
# 1920    846
# 1366    308
# 3840     43
# 2560     29
# 3200     27
# 1600     23
# 2304      6
# 2256      6
# 1440      4
# 2880      4
# 2400      4
# 2160      2
# 2736      1
# Name: count, dtype: int64

# %%
df.corr(numeric_only =True)['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# Ips            0.252208
# X_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
df['PPI'] = (df['X_res']**2 + df['y_res']**2)**0.5/df['Inches']

# %%
df.drop(columns =['X_res','y_res','Inches'], inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df.drop(columns =['ScreenResolution'], inplace = True)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     134
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# Intel Core M M7-6Y75 1.2GHz      1
# Intel Core i5 7200U 2.50GHz      1
# Intel Core i5 7200U 2.70GHz      1
# Intel Core i5 7200U 2.7GHz       1
# Intel Core i7 2.7GHz             1
# Name: count, Length: 118, dtype: int64

# %%
df["Cpu name"] = df['Cpu'].apply(lambda x: " ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       Cpu name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
def fetch_processor(text):
    if text =="Intel Core i5" or text =="Intel Core i7" or text =="Intel Core i3":
        return text
    else:
        if text.split()[0] == 'Intel':
            return "Other intel processor"
        else:
            return "AMD processor"

# %%
df["Cpu Brand"] =df["Cpu name"].apply(fetch_processor)

# %%
df.drop(columns = ['Cpu', 'Cpu name'], inplace =True)

# %%
df['Cpu Brand'].value_counts()
# Out:
# Cpu Brand
# Intel Core i7            527
# Intel Core i5            423
# Other intel processor    154
# Intel Core i3            136
# AMD processor             63
# Name: count, dtype: int64

# %%
df['Cpu Brand'].value_counts().plot( kind = 'bar')
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
sns.barplot(x =df["Cpu Brand"], y = df['Price'])
plt.xticks(rotation =90)
plt.show()

# %%
sns.barplot(x =df["Ram"], y = df['Price'])
plt.xticks(rotation =90)
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 64GB SSD                           1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 512GB SSD +  256GB SSD             1
# 32GB HDD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

# %%
new = df["Memory"].str.split("+", n = 1, expand = True)

# %%
df["first"]= new[0]
df["first"]= df["first"].str.strip()
df["second"]= new[1]

# %%
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
#       TouchScreen  Ips         PPI              Cpu Brand              first  \
# 0               0    1  226.983005          Intel Core i5            128 SSD
# 1               0    0  127.677940          Intel Core i5  128 Flash Storage
# 2               0    0  141.211998          Intel Core i5            256 SSD
# 3               0    1  220.534624          Intel Core i7            512 SSD
# 4               0    1  226.983005          Intel Core i5            256 SSD
# ...           ...  ...         ...                    ...                ...
# 1298            1    1  157.350512          Intel Core i7            128 SSD
# 1299            1    1  276.053530          Intel Core i7            512 SSD
# 1300            0    0  111.935204  Other intel processor   64 Flash Storage
# 1301            0    0  100.454670          Intel Core i7           1000 HDD
# 1302            0    0  100.454670  Other intel processor            500 HDD
#
#      second  Layer1HDD  Layer1SSD  Layer1Hybrid  Layer1Flash_Storage
# 0      None          0          1             0                    0
# 1      None          0          0             0                    1
# 2      None          0          1             0                    0
# 3      None          0          1             0                    0
# 4      None          0          1             0                    0
# ...     ...        ...        ...           ...                  ...
# 1298   None          0          1             0                    0
# 1299   None          0          1             0                    0
# 1300   None          0          0             0                    1
# 1301   None          1          0             0                    0
# 1302   None          1          0             0                    0
#
# [1303 rows x 18 columns]

# %%
df['first'] = df['first'].str.replace(r'\D', '', regex=True)

# %%
df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)
# Out:
# /tmp/ipykernel_2974/1710606452.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0", inplace = True)

# %%
df['second'] = df['second'].str.replace(r'\D', '',regex=True)

# %%
df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

# %%
df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(6)
# Out:
#      Company   TypeName  Ram               Memory                         Gpu  \
# 6      Apple  Ultrabook   16    256 Flash Storage     Intel Iris Pro Graphics
# 679     Acer     Gaming   16              256 SSD  Nvidia GeForce GTX 1050 Ti
# 995     Asus   Notebook    8              256 SSD       Intel HD Graphics 620
# 1065    Dell  Ultrabook    8              256 SSD       Intel HD Graphics 620
# 515     Asus    Netbook    2     32 Flash Storage       Intel HD Graphics 500
# 177      MSI     Gaming   32  512 SSD +  1000 HDD          Nvidia GTX 980 SLI
#
#            OpSys  Weight        Price  TouchScreen  Ips         PPI  \
# 6       Mac OS X    2.04  114017.6016            0    1  220.534624
# 679   Windows 10    2.50   69210.7200            0    0  141.211998
# 995   Windows 10    1.40   61272.0000            0    0  276.053530
# 1065  Windows 10    1.29   77682.2400            0    0  165.632118
# 515   Windows 10    1.10   13053.6000            0    0  135.094211
# 177   Windows 10    4.40  149130.7200            0    0  119.723216
#
#                   Cpu Brand   HDD  SSD  Hybrid  Flash_Storage
# 6             Intel Core i7     0    0       0            256
# 679           Intel Core i5     0  256       0              0
# 995           Intel Core i5     0  256       0              0
# 1065          Intel Core i7     0  256       0              0
# 515   Other intel processor     0    0       0             32
# 177           Intel Core i7  1000  512       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.corr(numeric_only = True)['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# Ips              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Flash_Storage','Hybrid'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  Ips         PPI      Cpu Brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R7 Graphics       1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu Brand'] = df['Gpu'].apply(lambda x: x.split()[0])

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df =df[df['Gpu Brand']!= 'ARM']

# %%
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1298  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1299  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1300  Lenovo            Notebook    2             Intel HD Graphics
# 1301      HP            Notebook    6            AMD Radeon R5 M330
# 1302    Asus            Notebook    4             Intel HD Graphics
#
#            OpSys  Weight        Price  TouchScreen  Ips         PPI  \
# 0          macOS    1.37   71378.6832            0    1  226.983005
# 1          macOS    1.34   47895.5232            0    0  127.677940
# 2          No OS    1.86   30636.0000            0    0  141.211998
# 3          macOS    1.83  135195.3360            0    1  220.534624
# 4          macOS    1.37   96095.8080            0    1  226.983005
# ...          ...     ...          ...          ...  ...         ...
# 1298  Windows 10    1.80   33992.6400            1    1  157.350512
# 1299  Windows 10    1.30   79866.7200            1    1  276.053530
# 1300  Windows 10    1.50   12201.1200            0    0  111.935204
# 1301  Windows 10    2.19   40705.9200            0    0  100.454670
# 1302  Windows 10    2.20   19660.3200            0    0  100.454670
#
#                   Cpu Brand   HDD  SSD Gpu Brand
# 0             Intel Core i5     0  128     Intel
# 1             Intel Core i5     0    0     Intel
# 2             Intel Core i5     0  256     Intel
# 3             Intel Core i7     0  512       AMD
# 4             Intel Core i5     0  256     Intel
# ...                     ...   ...  ...       ...
# 1298          Intel Core i7     0  128     Intel
# 1299          Intel Core i7     0  512     Intel
# 1300  Other intel processor     0    0     Intel
# 1301          Intel Core i7  1000    0       AMD
# 1302  Other intel processor   500    0     Intel
#
# [1302 rows x 14 columns]

# %%
sns.barplot(x =df["Gpu Brand"], y = df['Price'])
# Out:
# <Axes: xlabel='Gpu Brand', ylabel='Price'>

# %%
df.drop( columns= ['Gpu'], inplace = True)
# Out:
# /tmp/ipykernel_2974/3985000152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop( columns= ['Gpu'], inplace = True)

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
#              PPI              Cpu Brand   HDD  SSD Gpu Brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# 1     127.677940          Intel Core i5     0    0     Intel
# 2     141.211998          Intel Core i5     0  256     Intel
# 3     220.534624          Intel Core i7     0  512       AMD
# 4     226.983005          Intel Core i5     0  256     Intel
# ...          ...                    ...   ...  ...       ...
# 1298  157.350512          Intel Core i7     0  128     Intel
# 1299  276.053530          Intel Core i7     0  512     Intel
# 1300  111.935204  Other intel processor     0    0     Intel
# 1301  100.454670          Intel Core i7  1000    0       AMD
# 1302  100.454670  Other intel processor   500    0     Intel
#
#                         os
# 0                   Mac OS
# 1                   Mac OS
# 2     Other/Linux/ChromeOS
# 3                   Mac OS
# 4                   Mac OS
# ...                    ...
# 1298               Windows
# 1299               Windows
# 1300               Windows
# 1301               Windows
# 1302               Windows
#
# [1302 rows x 13 columns]

# %%
df.OpSys.value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x =df["OpSys"], y = df['Price'])
plt.xticks(rotation =90)
plt.show()

# %%
def fetch_os (os):
    if os == 'Windows 10' or os == 'Windows 7' or os == 'Windows 10 S':
        return "Windows"
    elif os == 'Mac OS X' or os == 'macOS':
        return "Mac OS"
    else:
        return "Other/Linux/ChromeOS"

# %%
df['os'] = df['OpSys'].apply(fetch_os)
# Out:
# /tmp/ipykernel_2974/840755816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os'] = df['OpSys'].apply(fetch_os)

# %%
df.drop(columns = "OpSys", inplace =True)
# Out:
# /tmp/ipykernel_2974/1030838739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns = "OpSys", inplace =True)

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
#              PPI              Cpu Brand   HDD  SSD Gpu Brand  \
# 0     226.983005          Intel Core i5     0  128     Intel
# 1     127.677940          Intel Core i5     0    0     Intel
# 2     141.211998          Intel Core i5     0  256     Intel
# 3     220.534624          Intel Core i7     0  512       AMD
# 4     226.983005          Intel Core i5     0  256     Intel
# ...          ...                    ...   ...  ...       ...
# 1298  157.350512          Intel Core i7     0  128     Intel
# 1299  276.053530          Intel Core i7     0  512     Intel
# 1300  111.935204  Other intel processor     0    0     Intel
# 1301  100.454670          Intel Core i7  1000    0       AMD
# 1302  100.454670  Other intel processor   500    0     Intel
#
#                         os
# 0                   Mac OS
# 1                   Mac OS
# 2     Other/Linux/ChromeOS
# 3                   Mac OS
# 4                   Mac OS
# ...                    ...
# 1298               Windows
# 1299               Windows
# 1300               Windows
# 1301               Windows
# 1302               Windows
#
# [1302 rows x 13 columns]

# %%
sns.barplot(x =df["os"], y = df['Price'])
plt.xticks(rotation =90)
plt.show()

# %%
sns.distplot(df["Weight"])
# Out:
# /tmp/ipykernel_2974/196129849.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Weight"])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x = df["Weight"],y = df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.heatmap(df.corr(numeric_only =True))
# Out:
# <Axes: >

# %%
sns.distplot(np.log(df['Price']))
# Out:
# /tmp/ipykernel_2974/3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# ## Split Input And Output Data

# %%
x = df.drop(columns =['Price'])
y = np. log(df['Price'])

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  TouchScreen  Ips         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
#                   Cpu Brand   HDD  SSD Gpu Brand                    os
# 0             Intel Core i5     0  128     Intel                Mac OS
# 1             Intel Core i5     0    0     Intel                Mac OS
# 2             Intel Core i5     0  256     Intel  Other/Linux/ChromeOS
# 3             Intel Core i7     0  512       AMD                Mac OS
# 4             Intel Core i5     0  256     Intel                Mac OS
# ...                     ...   ...  ...       ...                   ...
# 1298          Intel Core i7     0  128     Intel               Windows
# 1299          Intel Core i7     0  512     Intel               Windows
# 1300  Other intel processor     0    0     Intel               Windows
# 1301          Intel Core i7  1000    0       AMD               Windows
# 1302  Other intel processor   500    0     Intel               Windows
#
# [1302 rows x 12 columns]

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /home/user/.local/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/user/.local/lib/python3.9/site-packages (from sklearn) (1.4.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/user/.local/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/user/.local/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.5.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/user/.local/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/lib/python3/dist-packages (from scikit-learn->sklearn) (1.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## train & test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.15,random_state= 2)

# %%
x_train
# Out:
#       Company            TypeName  Ram  Weight  TouchScreen  Ips         PPI  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
#                   Cpu Brand   HDD  SSD Gpu Brand                    os
# 183           Intel Core i5     0  128     Intel               Windows
# 1141          Intel Core i7  1000  128    Nvidia               Windows
# 1049  Other intel processor     0    0     Intel  Other/Linux/ChromeOS
# 1020          Intel Core i3  1000    0     Intel               Windows
# 878           Intel Core i5  1000  128    Nvidia               Windows
# ...                     ...   ...  ...       ...                   ...
# 466           Intel Core i3   500    0    Nvidia               Windows
# 299           Intel Core i7     0  512    Nvidia               Windows
# 493           AMD processor  1000    0       AMD               Windows
# 527           Intel Core i3  2000    0    Nvidia  Other/Linux/ChromeOS
# 1193  Other intel processor     0    0     Intel                Mac OS
#
# [1106 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error

# %% [markdown]
# ## Creating pipeline

# %%
step1 = ColumnTransformer(transformers =[
    ('col_tnf',OneHotEncoder(sparse_output = False ,drop ='first'),[0,1,7,10,11])
],remainder ="passthrough")

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(x_train, y_train)
y_pred = pipe.predict(x_test)

print("R2 score",r2_score(y_test,y_pred))
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277448418485
# MAE 0.21017827976428904

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))
